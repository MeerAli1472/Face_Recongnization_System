# %%
from tkinter import*
from tkinter import ttk
from PIL import Image,ImageTk
from student_management_system import student
from train_dataset import Train
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-8ba7a873e1ad> in <module>
#       3 from PIL import Image,ImageTk
#       4 from student_management_system import student
# ----> 5 from train_dataset import Train
#       6 import os
#
# ModuleNotFoundError: No module named 'train_dataset'

# %%
class Face_Reconization_System:
    def __init__(self,root):
        self.root=root
        self.root.geometry("1560x768+0+0")
        self.root.minsize(1024,768)
        self.root.title("Face Rcongnization System")
        
        
        #first image
        self.img = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\IMS1.gif")
        self.img = self.img.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg=ImageTk.PhotoImage(self.img)
        
        f_lbl = Label(self.root,image=self.photoimg)
        f_lbl.place(x=0,y=0,width=500,height=120)
        
        
        #second image
        self.img1 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\FacialRecognition.gif")
        self.img1 = self.img1.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg1=ImageTk.PhotoImage(self.img1)
        
        f_lbl = Label(self.root,image=self.photoimg1)
        f_lbl.place(x=500,y=0,width=500,height=120)
        
        
#         #third image
        self.img2 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\ims3.gif")
        self.img2 = self.img2.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg2=ImageTk.PhotoImage(self.img2)
        
        f_lbl = Label(self.root,image=self.photoimg2)
        f_lbl.place(x=1000,y=0,width=500,height=120)
        
#         #background image
        self.img3 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\bgimg1.gif")
        self.img3 = self.img3.resize((1530,710),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg3=ImageTk.PhotoImage(self.img3)
        
        bg_img = Label(self.root,image=self.photoimg3)
        bg_img.place(x=0,y=120,width=1530,height=710)
        
        title_lbl = Label(bg_img,text="FACE RECONGNIZATION ATTENDACE SYSTEM",font=("Helvetica",30,"bold"),bg="white",fg="dark turquoise")
        title_lbl.place(x=0,y=0,width=1530,height=45)
        
        
        #std button
        img4 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\std1.png")
        img4 = img4.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg4=ImageTk.PhotoImage(img4)
        
        b1 =Button(bg_img,image=self.photoimg4,command=self.student_details,cursor="hand2")
        b1.place(x=200,y=120,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Student Details",command=self.student_details,cursor="hand2",font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=200,y=300,width=180,height=30)
        
        #detect face button
        img5 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\face detecter.gif")
        img5 = img5.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg5=ImageTk.PhotoImage(img5)
        
        b1 =Button(bg_img,image=self.photoimg5,cursor="hand2")
        b1.place(x=500,y=120,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Face Detecter",cursor="hand2",font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=500,y=300,width=180,height=30)
        
        
        
        #Face attendanc button
        img6 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\FacialRecognitionsystem.png")
        img6 = img6.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg6=ImageTk.PhotoImage(img6)
        
        b1 =Button(bg_img,image=self.photoimg6,cursor="hand2")
        b1.place(x=800,y=120,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Attendance",cursor="hand2",font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=800,y=300,width=180,height=30)
        
        
        #Help Butthon
        img7 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\help.png")
        img7 = img7.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg7=ImageTk.PhotoImage(img7)
        
        b1 =Button(bg_img,image=self.photoimg7,cursor="hand2")
        b1.place(x=1100,y=120,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Help Desk",cursor="hand2",font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=1100,y=300,width=180,height=30)
        
        
        #Train Face button
        img8 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\tt.gif")
        img8 = img8.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg8=ImageTk.PhotoImage(img8)
        
        b1 =Button(bg_img,image=self.photoimg8,cursor="hand2",command=self.train_data)
        b1.place(x=200,y=380,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Train Data",command=self.train_data,cursor="hand2",font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=200,y=550,width=180,height=30)
        
        
        #photo Face Button
        img9 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\photo.gif")
        img9 = img9.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg9=ImageTk.PhotoImage(img9)
        
        b1 =Button(bg_img,image=self.photoimg9,cursor="hand2",command=self.open_img)
        b1.place(x=500,y=380,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Photos",cursor="hand2",command=self.open_img,font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=500,y=550,width=180,height=30)
        
        
        
        #Developer Button
        img10 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\dev.gif")
        img10 = img10.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg10=ImageTk.PhotoImage(img10)
        
        b1 =Button(bg_img,image=self.photoimg10,cursor="hand2")
        b1.place(x=800,y=380,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Developer",cursor="hand2",font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=800,y=550,width=180,height=30)
        
        
        #Exit Button
        img11 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\exit.gif")
        img11 = img11.resize((220,220),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg11=ImageTk.PhotoImage(img11)
        
        b1 =Button(bg_img,image=self.photoimg11,cursor="hand2")
        b1.place(x=1100,y=380,width=180,height=180)
        
        b1_1 =Button(bg_img,text = "Exit",cursor="hand2",font=("times new roman",15,"bold"),bg="darkblue",fg="white")
        b1_1.place(x=1100,y=550,width=180,height=30)
        
        
    def open_img(self):
        os.startfile("data")
        
        
        
    def student_details(self):
        self.new_window = Toplevel(self.root)
        self.app=student(self.new_window)
        
    def train_data(self):
        self.new_window = Toplevel(self.root)
        self.app=Train(self.new_window)
        
if __name__ == "__main__":
    root=Tk()
    obj = Face_Reconization_System(root)
    root.mainloop()
