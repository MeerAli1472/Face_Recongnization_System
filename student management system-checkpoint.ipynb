# %%
from tkinter import*
from tkinter import ttk
from PIL import Image,ImageTk

# %%
class student:
    def __init__(self,root):
        self.root=root
        self.root.geometry("1560x768+0+0")
        self.root.minsize(1024,768)
        self.root.title("Face Rcongnization System")
        
        
        #first image
        self.img = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\std.png")
        self.img = self.img.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg=ImageTk.PhotoImage(self.img)
        
        f_lbl = Label(self.root,image=self.photoimg)
        f_lbl.place(x=0,y=0,width=500,height=120)
        
        
        #second image
        self.img1 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\std1.png")
        self.img1 = self.img1.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg1=ImageTk.PhotoImage(self.img1)
        
        f_lbl = Label(self.root,image=self.photoimg1)
        f_lbl.place(x=500,y=0,width=500,height=120)
        
        
        
        #third image
        self.img2 = Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\std.png")
        self.img2 = self.img2.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg2=ImageTk.PhotoImage(self.img2)
        
        f_lbl = Label(self.root,image=self.photoimg2)
        f_lbl.place(x=1000,y=0,width=500,height=120)
        
        
        title_lbl = Label(self.root,text="STUDENT MANAGEMENT SYSTEM",font=("Helvetica",30,"bold"),bg="white",fg="dark turquoise")
        title_lbl.place(x=0,y=100,width=1530,height=45)
        
        
        main_frame=Frame(self.root,bd=4,bg="white")
        main_frame.place(x=0,y=150,width=1480,height=600)
        
        #left label frame
        left_frame=LabelFrame(main_frame,bd=4,bg="white",relief=RIDGE,text="Student Details",font=("times new roman",12,"bold"))
        left_frame.place(x=10,y=10,width=600,height=530)
        
        
        self.img4= Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\std3.png")
        self.img4= self.img4.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg4=ImageTk.PhotoImage(self.img4)
        
        f_lbl = Label(left_frame,image=self.photoimg4)
        f_lbl.place(x=0,y=0,width=500,height=120)
       
        #cuurrent course
        current_course_frame=LabelFrame(left_frame,bd=2,bg="white",relief=RIDGE,text="current Course Information",font=("times new roman",12,"bold"))
        current_course_frame.place(x=5,y=120,width=550,height=120)
        
        #Department combobox
        dep_label=Label(current_course_frame,text="Department",font=("times new roman",12,"bold"),bg="white")
        dep_label.grid(row=0,column=0,padx=10,sticky=W)
        
        dep_combo=ttk.Combobox(current_course_frame,state="readonly",font=("times new roman",12,"bold"),width=15)
        dep_combo["values"]=("Select Department","computer","IT","Bussiness") 
        dep_combo.current(0)                                                     
        dep_combo.grid(row=0,column=1,padx=2,pady=10,sticky=W)
        
        
        #course combobox
        course_label=Label(current_course_frame,text="Course",font=("times new roman",12,"bold"),bg="white")
        course_label.grid(row=0,column=2,padx=10,sticky=W)
        
        course_combo=ttk.Combobox(current_course_frame,state="readonly",font=("times new roman",12,"bold"),width=15)
        course_combo["values"]=("Select Course","CS","DS","SE","SS") 
        course_combo.current(0)                                                     
        course_combo.grid(row=0,column=3,padx=2,pady=10,sticky=W)
        
        
        #Year combobox
        year_label=Label(current_course_frame,text="Year",font=("times new roman",12,"bold"),bg="white")
        year_label.grid(row=1,column=0,padx=10,sticky=W)
        
        year_combo=ttk.Combobox(current_course_frame,state="readonly",font=("times new roman",12,"bold"),width=15)
        year_combo["values"]=("Select Year","2020-21","2021-22","2022-23","2023-24") 
        year_combo.current(0)                                                     
        year_combo.grid(row=1,column=1,padx=2,pady=10,sticky=W)
        
        
        #Semester combobox
        semester_label=Label(current_course_frame,text="Semester",font=("times new roman",12,"bold"),bg="white")
        semester_label.grid(row=1,column=2,padx=10,sticky=W)
        
        semester_combo=ttk.Combobox(current_course_frame,state="readonly",font=("times new roman",12,"bold"),width=15)
        semester_combo["values"]=("Select Semester","1","2","3","4","5","6","7","8") 
        semester_combo.current(0)                                                     
        semester_combo.grid(row=1,column=3,padx=2,pady=10,sticky=W)
        
        
        #Class student information
        class_student_frame=LabelFrame(left_frame,bd=2,bg="white",relief=RIDGE,text="class Information",font=("times new roman",12,"bold"))
        class_student_frame.place(x=5,y=245,width=550,height=260)
        
        #std label
        student_label=Label(class_student_frame,text="StudentID:",font=("times new roman",12,"bold"),bg="white")
        student_label.grid(row=0,column=0,padx=10,sticky=W)
        
        #std entrybox
        std_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        std_entry.grid(row=0,column=1,padx=10,pady=5,sticky=W)
        
        
        #name label
        name_label=Label(class_student_frame,text="Name:",font=("times new roman",12,"bold"),bg="white")
        name_label.grid(row=0,column=2,padx=10,sticky=W)
        
        #std entrybox
        name_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        name_entry.grid(row=0,column=3,padx=10,pady=5,sticky=W)
        
        
        #class label
        class_label=Label(class_student_frame,text="Class Section:",font=("times new roman",12,"bold"),bg="white")
        class_label.grid(row=1,column=0,padx=10,sticky=W)
        
        #class entrybox
        class_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        class_entry.grid(row=1,column=1,padx=10,pady=5,sticky=W)
        
        
        #roll no label
        roll_no_label=Label(class_student_frame,text="Roll No:",font=("times new roman",12,"bold"),bg="white")
        roll_no_label.grid(row=1,column=2,padx=10,pady=5,sticky=W)
        
        #std entrybox
        roll_no_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        roll_no_entry.grid(row=1,column=3,padx=10,pady=5,sticky=W)
        
        
        #Gender label
        gender_label=Label(class_student_frame,text="Gender:",font=("times new roman",12,"bold"),bg="white")
        gender_label.grid(row=2,column=0,padx=10,sticky=W)
        
        #Gender entrybox
        gender_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        gender_entry.grid(row=2,column=1,padx=10,pady=5,sticky=W)
        
        
        #DOB label
        DOB_label=Label(class_student_frame,text="DOB:",font=("times new roman",12,"bold"),bg="white")
        DOB_label.grid(row=2,column=2,padx=10,sticky=W)
        
        #DOB entrybox
        DOB_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        DOB_entry.grid(row=2,column=3,padx=10,pady=5,sticky=W)
        
        
        #Email label
        Email_label=Label(class_student_frame,text="Email:",font=("times new roman",12,"bold"),bg="white")
        Email_label.grid(row=3,column=0,padx=10,sticky=W)
        
        #Email entrybox
        Email_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        Email_entry.grid(row=3,column=1,padx=10,pady=5,sticky=W)
        
        
        #Address label
        Address_label=Label(class_student_frame,text="Address:",font=("times new roman",12,"bold"),bg="white")
        Address_label.grid(row=4,column=0,padx=10,sticky=W)
        
        #Address entrybox
        Address_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        Address_entry.grid(row=4,column=1,padx=10,pady=5,sticky=W)
        
        
        #phone_no label
        phone_label=Label(class_student_frame,text="Phone No:",font=("times new roman",12,"bold"),bg="white")
        phone_label.grid(row=3,column=2,padx=10,sticky=W)
        
        #Phone no entrybox
        phone_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        phone_entry.grid(row=3,column=3,padx=10,pady=5,sticky=W)
        
        
        #Teacher label
        phone_label=Label(class_student_frame,text="Teacher Name:",font=("times new roman",12,"bold"),bg="white")
        phone_label.grid(row=4,column=2,padx=10,sticky=W)
        
        #Teacher entrybox
        phone_entry = ttk.Entry(class_student_frame,width=15,font=("times new roman",12,"bold"))
        phone_entry.grid(row=4,column=3,padx=10,pady=5,sticky=W)
        
        #radio button
        radio_btn = ttk.Radiobutton(class_student_frame,text="Take Photo",value="Yes")
        radio_btn.grid(row=6,column=0)
        
        radio_btn2 = ttk.Radiobutton(class_student_frame,text="No Photo",value="No")
        radio_btn2.grid(row=6,column=1)
        
        
#       button frame
        btn_frame=LabelFrame(class_student_frame,bd=2,bg="white",relief=RIDGE)
        btn_frame.place(x=0,y=195,width=545,height=180)
        
        #save_btn
        save_btn=Button(btn_frame,text="Save",font=("times new roman",12,"bold"),bg="cyan",fg="black")
        save_btn.grid(row=0,column=0,padx=5,pady=5)
        
        #update_btn
        update_btn=Button(btn_frame,text="Update",font=("times new roman",12,"bold"),bg="cyan",fg="black")
        update_btn.grid(row=0,column=1,padx=5,pady=5)
        
        #delete_btn
        delete_btn=Button(btn_frame,text="Delete",font=("times new roman",12,"bold"),bg="cyan",fg="black")
        delete_btn.grid(row=0,column=2,padx=5,pady=5)
        
        #reset_btn
        reset_btn=Button(btn_frame,text="Reset",font=("times new roman",12,"bold"),bg="cyan",fg="black")
        reset_btn.grid(row=0,column=3,padx=5,pady=5)
        
        #take photo_btn
        takephoto_btn=Button(btn_frame,text="Take Photo",width=15,font=("times new roman",12,"bold"),bg="cyan",fg="black")
        takephoto_btn.grid(row=0,column=4,padx=5,pady=5)
        
        #update photo_btn
        updatphoto_btn=Button(btn_frame,text="Update Photo",width=15,font=("times new roman",12,"bold"),bg="cyan",fg="black")
        updatphoto_btn.grid(row=0,column=5,padx=5,pady=5)
        
        
        
        #right label framW,font=("times new roman",12,"bold")
        right_frame=LabelFrame(main_frame,bd=4,bg="white",relief=RIDGE,text="Student Details",font=("times new roman",12,"bold"))
        right_frame.place(x=700,y=10,width=600,height=520)
        
        
        self.img5= Image.open(r"C:\Users\MEER\Desktop\Face Recongnization system\images\std3.png")
        self.img5= self.img5.resize((500,130),Image.ANTIALIAS)   #used to change high level image to low level image
        self.photoimg5=ImageTk.PhotoImage(self.img5)
        
        f_lbl = Label(right_frame,image=self.photoimg5)
        f_lbl.place(x=0,y=0,width=500,height=120)
        
        #Search Frame
        search_frame=LabelFrame(right_frame,bd=2,bg="white",relief=RIDGE,text="Search System",font=("times new roman",12,"bold"))
        search_frame.place(x=10,y=100,width=560,height=70)
        
        
        #search label
        search_label=Label(search_frame,text="Search By:",font=("times new roman",12,"bold"),bg="white")
        search_label.grid(row=0,column=0,padx=10,sticky=W)
        
        
        #search combobox
        search_combo=ttk.Combobox(search_frame,state="readonly",font=("times new roman",12,"bold"),width=15)
        search_combo["values"]=("Select","Roll_no") 
        search_combo.current(0)                                                     
        search_combo.grid(row=0,column=1,padx=2,pady=10,sticky=W)
        
        #search entrybox
        search_entry = ttk.Entry(search_frame,width=15,font=("times new roman",12,"bold"))
        search_entry.grid(row=0,column=2,padx=10,pady=5,sticky=W)
        
        #search_btn
        search_btn=Button(search_frame,width=7,text="Search",font=("times new roman",12,"bold"),bg="cyan",fg="black")
        search_btn.grid(row=0,column=3,padx=5,pady=5)
        
        #showall_btn
        showall_btn=Button(search_frame,text="Show All",font=("times new roman",12,"bold"),bg="cyan",fg="black")
        showall_btn.grid(row=0,column=4,padx=5,pady=5)
        
        
        #table Frame
        table_frame=Frame(right_frame,bd=2,bg="white",relief=RIDGE)
        table_frame.place(x=10,y=170,width=560,height=300)
        
        #scroll bar_x
        scroll_x = ttk.Scrollbar(table_frame,orient=HORIZONTAL)
        scroll_y = ttk.Scrollbar(table_frame,orient=VERTICAL)
        self.student_table = ttk.Treeview(table_frame,column=("Dep","Course","Year","Sem","Id","name","Div","Roll","Gender","DOB","Email","Phone","Address","Teacher","Photo"),xscrollcommand=scroll_x.set,yscrollcommand=scroll_y.set)
        scroll_x.pack(side=BOTTOM,fill=X)
        scroll_y.pack(side=RIGHT,fill=Y)
        scroll_x.config(command=self.student_table.xview)
        scroll_y.config(command=self.student_table.yview)
        
        self.student_table.heading("Dep",text="Department")
        self.student_table.heading("Course",text="Course")
        self.student_table.heading("Year",text="Year")
        self.student_table.heading("Sem",text="Semester")
        self.student_table.heading("Id",text="StudentID")
        self.student_table.heading("name",text="Name")
        self.student_table.heading("Div",text="Division")
        self.student_table.heading("Roll",text="RollNo")
        self.student_table.heading("Gender",text="Gender")
        self.student_table.heading("DOB",text="DOB")
        self.student_table.heading("Email",text="Email")
        self.student_table.heading("Phone",text="Phone")
        self.student_table.heading("Address",text="Address")
        self.student_table.heading("Teacher",text="Teacher")
        self.student_table.heading("Photo",text="PhotoSample")
        self.student_table["show"]="headings"
        
        #set column width
        self.student_table.column("Dep",width=100)
        self.student_table.column("Course",width=100)
        self.student_table.column("Year",width=100)
        self.student_table.column("Sem",width=100)
        self.student_table.column("Id",width=100)
        self.student_table.column("name",width=100)
        self.student_table.column("Div",width=100)
        self.student_table.column("Roll",width=100)
        self.student_table.column("Gender",width=100)
        self.student_table.column("DOB",width=100)
        self.student_table.column("Email",width=100)
        self.student_table.column("Phone",width=100)
        self.student_table.column("Address",width=100)
        self.student_table.column("Teacher",width=100)
        self.student_table.column("Photo",width=100)
        
        self.student_table.pack(fill=BOTH,expand=1)
        
        
        
if __name__ == "__main__":
    root=Tk()
    obj = student(root)
    root.mainloop()
